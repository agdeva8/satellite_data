# %%
import datetime as dt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
anom_sd1 = pd.read_excel('Anom_SD1.xlsx')

# %%
anom_sd1.head()
# Out:
#         Pkey             128           1509         2627      315        2108  \
# 0   DISTRICT        Adilabad           Agra   Ahmadnagar   Aizawl       Ajmer
# 1  DT_CEN_CD               1             15           26        3          21
# 2  ST_CEN_CD              28              9           27       15           8
# 3      ST_NM  Andhra Pradesh  Uttar Pradesh  Maharashtra  Mizoram   Rajasthan
# 4      Label             NaN     Large City          NaN      NaN  Large City
#
#            527       1132           1209            4823      ...       \
# 0        Akola  Alappuzha        Aligarh       Alirajpur      ...
# 1            5         11             12              48      ...
# 2           27         32              9              23      ...
# 3  Maharashtra     Kerala  Uttar Pradesh  Madhya Pradesh      ...
# 4          NaN        NaN            NaN             NaN      ...
#
#   Unnamed: 2308 Unnamed: 2309 Unnamed: 2310 Unnamed: 2311 Unnamed: 2312  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#   Unnamed: 2313 Unnamed: 2314 Unnamed: 2315 Unnamed: 2316 Unnamed: 2317
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 2318 columns]

# %%
cols = anom_sd1.columns.tolist()

# %%
raw = anom_sd1[cols[:cols.index( u'MA(TS-MA)')]]
raw.columns = raw[0:1].values.tolist()
raw = raw[1:-1]

# %%
raw_cols = raw.columns.tolist()

# %%
std_all_years = list()

# %%
states_list = raw[2:3].values.tolist()[0]

# %%
raw_states = raw.copy(deep=True)

# %%
raw_states.columns = states_list

# %%
raw_states = raw_states[5:]

# %%
raw_states
# Out:
#                   ST_NM Andhra Pradesh Uttar Pradesh Maharashtra   Mizoram  \
# 6   2012-04-01 00:00:00       -0.27956      0.485294    -0.12025 -0.391341
# 7   2012-05-01 00:00:00      -0.277922      0.277965   -0.146679 -0.476825
# 8   2012-06-01 00:00:00      -0.847498      0.249184   -0.302956    -0.687
# 9   2012-07-01 00:00:00      -0.821129     -0.639832   -0.622307  -0.56143
# 10  2012-08-01 00:00:00      -0.651567    -0.0240625   -0.172842 -0.433613
# 11  2012-09-01 00:00:00      -0.629271      0.089647   -0.167754 -0.352601
# 12  2012-10-01 00:00:00      -0.316618      0.339892   -0.169107 -0.452034
# 13  2012-11-01 00:00:00      -0.318966      0.618683  -0.0631883 -0.637931
# 14  2012-12-01 00:00:00      -0.461837      0.439145    -0.19803 -0.814498
# 15  2013-01-01 00:00:00      -0.399752      0.294907   -0.152742 -0.691985
# 16  2013-02-01 00:00:00      -0.296052      0.482937   -0.123249 -0.590672
# 17  2013-03-01 00:00:00      -0.210982      0.380387  -0.0816794 -0.374328
# 18  2013-04-01 00:00:00      -0.172367      0.360451  -0.0686934  -0.22851
# 19  2013-05-01 00:00:00      -0.290715      0.350582  -0.0815744 -0.402777
# 20  2013-06-01 00:00:00      -0.721198      0.197189   -0.687874 -0.456462
# 21  2013-07-01 00:00:00      -0.590384     -0.116569   -0.275464 -0.583332
# 22  2013-08-01 00:00:00      -0.417773      0.119326   -0.240984 -0.610207
# 23  2013-09-01 00:00:00      -0.378596      0.266635   -0.176654 -0.421066
# 24  2013-10-01 00:00:00      -0.263059      0.398716   -0.157231 -0.304189
# 25  2013-11-01 00:00:00      -0.209408       0.65275  -0.0240466 -0.485602
# 26  2013-12-01 00:00:00      -0.352846      0.472639   -0.185632 -0.610348
# 27  2014-01-01 00:00:00      -0.368733      0.354983   -0.174566 -0.589317
# 28  2014-02-01 00:00:00      -0.296992      0.438402   -0.108003 -0.581771
# 29  2014-03-01 00:00:00      -0.185612      0.492612  -0.0862669 -0.391722
# 30  2014-04-01 00:00:00      -0.129614      0.423038  -0.0515627 -0.308608
# 31  2014-05-01 00:00:00      -0.279378      0.315148   -0.131815 -0.480609
# 32  2014-06-01 00:00:00      -0.326197      0.242873   -0.171039 -0.564096
# 33  2014-07-01 00:00:00      -0.471916      0.186969  -0.0914951 -0.548428
# 34  2014-08-01 00:00:00      -0.290209      0.114592   -0.248089 -0.473275
# 35  2014-09-01 00:00:00      -0.235086      0.210655  -0.0919759 -0.378901
# 36  2014-10-01 00:00:00       -0.29969      0.590325   -0.130815 -0.482873
# 37  2014-11-01 00:00:00       -0.50849      0.497499   -0.221287 -0.905063
# 38  2014-12-01 00:00:00      -0.329531      0.453129  -0.0908247 -0.453817
# 39  2015-01-01 00:00:00      -0.320597      0.363584   -0.112957 -0.529714
# 40  2015-02-01 00:00:00      -0.124056      0.476112  -0.0211411 -0.376881
# 41  2015-03-01 00:00:00      -0.185393       0.48299  -0.0598862 -0.305445
# 42  2015-04-01 00:00:00      -0.217489      0.456282  -0.0303778 -0.399446
# 43  2015-05-01 00:00:00      -0.291036      0.293457  -0.0929618 -0.467175
# 44  2015-06-01 00:00:00      -0.516548      0.258702   -0.145937 -0.616152
# 45  2015-07-01 00:00:00      -0.674431      0.186604    -0.14089  -0.59464
# 46  2015-08-01 00:00:00      -0.342717      0.208022  -0.0460267 -0.635988
# 47  2015-09-01 00:00:00      -0.247559      0.178421   -0.139296 -0.524833
# 48  2015-10-01 00:00:00      -0.258571      0.382886  -0.0829798 -0.405111
# 49  2015-11-01 00:00:00        -0.2391      0.589056   0.0426315 -0.504867
# 50  2015-12-01 00:00:00       -0.26316      0.496559  -0.0529862 -0.467364
# 51  2016-01-01 00:00:00      -0.389737      0.413365   -0.107144 -0.746126
# 52  2016-02-01 00:00:00      -0.380125      0.415574  -0.0831574 -0.783759
# 53  2016-03-01 00:00:00      -0.314358      0.411762  -0.0348662 -0.628499
# 54  2016-04-01 00:00:00      -0.281975      0.398779  -0.0456069 -0.544053
# 55  2016-05-01 00:00:00      -0.234032      0.313919   0.0173466 -0.469646
# 56  2016-06-01 00:00:00      -0.314433       0.24534  -0.0594422 -0.541445
# 57  2016-07-01 00:00:00      -0.646667      0.218811   -0.247034  -0.59589
# 58  2016-08-01 00:00:00      -0.338502      0.166088   -0.185813 -0.564339
# 59  2016-09-01 00:00:00      -0.214967      0.257873  -0.0605903 -0.447987
# 60  2016-10-01 00:00:00      -0.212506      0.516887   0.0268928 -0.465115
# 61  2016-11-01 00:00:00      -0.368132      0.528309 -0.00171643 -0.663965
# 62  2016-12-01 00:00:00      -0.408759      0.446718  -0.0880181 -0.664986
# 63  2017-01-01 00:00:00      -0.289077       0.47516  -0.0198243 -0.478867
# 64  2017-02-01 00:00:00     -0.0904401      0.557504   0.0244717 -0.460152
# 65  2017-03-01 00:00:00      -0.146943      0.500859   0.0457482 -0.375487
#
#      Rajasthan Maharashtra      Kerala Uttar Pradesh Madhya Pradesh    ...     \
# 6   -0.0500899   -0.178565    -0.72856      0.101265      -0.261904    ...
# 7    -0.115087   -0.204629    -0.27689    -0.0969448        -0.3232    ...
# 8    -0.134222   -0.805423   -0.266805     -0.109144      -0.610443    ...
# 9    -0.138333    -0.83466   -0.428331     -0.436215      -0.462081    ...
# 10   -0.356269   -0.431333  -0.0916265     -0.211999      -0.552248    ...
# 11  -0.0847797   -0.264081    -0.10149     0.0156309      -0.433579    ...
# 12 -0.00865667   -0.189121   -0.829921     0.0483934      -0.335405    ...
# 13   0.0158698   -0.191809   -0.143478      0.301094      -0.498278    ...
# 14   -0.120637   -0.257076  -0.0896875     0.0910333      -0.569324    ...
# 15   -0.111872   -0.178893   -0.132826   -0.00936896      -0.477473    ...
# 16   -0.018044   -0.116855  -0.0401067      0.198538      -0.352417    ...
# 17  -0.0303042    -0.13092  -0.0294701      0.105212       -0.28074    ...
# 18  -0.0161855   -0.135999  -0.0306256      0.096568      -0.215591    ...
# 19  0.00979776   -0.157201   -0.171343      0.075743      -0.215986    ...
# 20  -0.0722838   -0.736914   -0.475445      -0.05549      -0.347356    ...
# 21   -0.260643   -0.451293   -0.490751     -0.289213      -0.727219    ...
# 22   -0.263006   -0.284022   -0.526516     -0.409737      -0.551089    ...
# 23  -0.0710489   -0.162651   -0.213077    -0.0566511        -0.4339    ...
# 24  -0.0361171   -0.211512  -0.0584582      0.068519      -0.382214    ...
# 25   0.0526675    -0.11934   -0.069914      0.339464      -0.339273    ...
# 26  -0.0457829   -0.194478  -0.0314693      0.184955      -0.442689    ...
# 27  -0.0694804   -0.153708  -0.0120901       0.16094      -0.423554    ...
# 28  -0.0179426   -0.107568  0.00848449      0.201329      -0.353443    ...
# 29  0.00977246   -0.108711   0.0101085      0.215249      -0.269242    ...
# 30  -0.0148299   -0.118469  -0.0393613      0.143739      -0.151053    ...
# 31   0.0107024   -0.186452  -0.0786191     0.0272712      -0.229615    ...
# 32   -0.107508   -0.247805   -0.114501     -0.113007      -0.452101    ...
# 33   -0.100597   -0.324326  -0.0660395     -0.165706      -0.460915    ...
# 34  -0.0708133   -0.213769   -0.274307    -0.0978837      -0.426263    ...
# 35  -0.0078859   -0.151543  -0.0262433    -0.0798745      -0.345552    ...
# 36   0.0468446   -0.196567   -0.117488      0.310397      -0.403789    ...
# 37   -0.105339   -0.339908    -0.11658      0.205445      -0.616146    ...
# 38   0.0380724   -0.103606  -0.0702951      0.160426      -0.331095    ...
# 39    0.031605   -0.150575  -0.0393417     0.0644799      -0.313657    ...
# 40   0.0563816    -0.03226    0.061561      0.223998      -0.207702    ...
# 41   0.0262834   -0.116069 -0.00754253      0.132526      -0.216191    ...
# 42   0.0536081   -0.105879   0.0212815     0.0588383      -0.177854    ...
# 43   -0.034626    -0.15688  -0.0117902     0.0173536      -0.210086    ...
# 44  -0.0999931   -0.735387   0.0516608    -0.0978882        -0.5106    ...
# 45   -0.180891   -0.365156  -0.0480752     -0.083177        -0.5274    ...
# 46    -0.10217   -0.254918    0.124466     -0.168596      -0.440843    ...
# 47  -0.0431866   -0.188157  -0.0108267    -0.0969288       -0.38406    ...
# 48  0.00926552   -0.155831   0.0104824    -0.0158441      -0.310394    ...
# 49   0.0862604   -0.103065   -0.666841      0.341665      -0.289888    ...
# 50   0.0488427  -0.0870302  -0.0505088       0.32428      -0.284775    ...
# 51 -0.00689543   -0.157552   -0.101769      0.242541      -0.398445    ...
# 52 -0.00831213  -0.0924945   -0.101136      0.250069      -0.337093    ...
# 53  -0.0118246  -0.0897858  0.00520638      0.261099      -0.231307    ...
# 54   0.0302477   -0.128473 -0.00427016      0.208551      -0.167809    ...
# 55 -0.00225215    -0.10972  0.00660076      0.114223      -0.210339    ...
# 56  -0.0505896   -0.148558   0.0614005     0.0689287      -0.278219    ...
# 57   -0.173383   -0.446817   -0.102229     0.0864146      -0.644905    ...
# 58   -0.170036   -0.274304   0.0433177    -0.0176845      -0.603614    ...
# 59  -0.0247873    -0.16227 -0.00676887     0.0649203      -0.378524    ...
# 60    0.111704   -0.110253   0.0437122      0.341455      -0.307797    ...
# 61  -0.0141394   -0.197984   -0.108022      0.317053       -0.43446    ...
# 62  -0.0452211   -0.164972  -0.0405753      0.295412      -0.429785    ...
# 63  -0.0021812  -0.0703175  -0.0077414      0.322929       -0.24019    ...
# 64   0.0705744 -0.00257651   0.0816779      0.397241      -0.152005    ...
# 65   0.0731911  -0.0344136   0.0869958      0.332724     -0.0991418    ...
#
#    Arunanchal Pradesh Meghalaya Madhya Pradesh Arunanchal Pradesh  Nagaland  \
# 6           -0.478069 -0.419745      -0.285205          -0.614269 -0.398627
# 7           -0.592904 -0.419692      -0.346414          -0.552045 -0.515456
# 8           -0.639329 -0.671749      -0.703157          -0.723896 -0.577814
# 9           -0.659532 -0.607226      -0.797127          -0.787057 -0.777536
# 10          -0.502719 -0.444296      -0.623049          -0.586986 -0.443903
# 11          -0.384212 -0.534293      -0.358845          -0.452072 -0.374709
# 12          -0.472622 -0.395558      -0.280333          -0.491983 -0.400847
# 13          -0.771258 -0.657377      -0.412922          -0.768817  -0.60013
# 14           -1.09751 -0.869336      -0.535657           -1.06818 -0.700664
# 15          -0.812809  -0.67885      -0.478958          -0.792012 -0.678851
# 16           -0.61583 -0.555871      -0.391645           -0.77341 -0.418101
# 17          -0.617473 -0.365941      -0.293216          -0.633022 -0.476457
# 18          -0.541683 -0.154564      -0.224066          -0.618622 -0.424502
# 19          -0.527964 -0.463041      -0.259019           -0.57392 -0.386548
# 20          -0.465151 -0.399474      -0.577489          -0.477534 -0.424364
# 21           -0.70247 -0.618316      -0.534659          -0.797778 -0.460105
# 22          -0.607913 -0.595694      -0.476638          -0.677892 -0.575013
# 23          -0.475381 -0.407614      -0.350702          -0.558415 -0.448051
# 24           -0.25037 -0.258898       -0.24425          -0.298622 -0.194574
# 25          -0.514192 -0.464672      -0.242472          -0.547022 -0.476559
# 26           -0.65205 -0.565206      -0.385005          -0.685093 -0.522464
# 27           -0.73106 -0.638532      -0.367608          -0.719421 -0.525518
# 28          -0.615517 -0.599315      -0.331482          -0.639608 -0.540236
# 29           -0.62401 -0.293452      -0.239755          -0.612266 -0.200774
# 30           -0.45249 -0.322574      -0.178663           -0.47714  -0.15563
# 31          -0.587386 -0.576331      -0.297816          -0.737596 -0.581108
# 32          -0.530023 -0.574692       -0.41933          -0.623467 -0.494856
# 33          -0.584598 -0.557852      -0.519227          -0.589358 -0.466739
# 34          -0.552116  -0.54019      -0.406035          -0.640216 -0.483084
# 35          -0.517815 -0.372504      -0.253615          -0.542628 -0.431445
# 36          -0.508962 -0.452127      -0.344136          -0.624241 -0.441101
# 37          -0.973366 -0.786181      -0.616538           -1.19686 -0.731215
# 38          -0.554733 -0.475623      -0.367571          -0.610111 -0.377631
# 39          -0.632888 -0.499289      -0.345812          -0.643376 -0.428987
# 40           -0.38714 -0.357045      -0.250989          -0.351989 -0.315577
# 41          -0.387906 -0.161686      -0.246305          -0.482261 -0.187921
# 42          -0.543601 -0.432472      -0.196505          -0.599922 -0.447322
# 43          -0.503805 -0.405747      -0.336398          -0.604274 -0.438967
# 44          -0.522757 -0.445778      -0.476704          -0.635299 -0.483363
# 45          -0.549877 -0.519084      -0.415494          -0.584341 -0.422845
# 46          -0.759048 -0.586786      -0.371346           -0.82399 -0.586768
# 47          -0.553052 -0.479587      -0.322287          -0.581001 -0.499612
# 48          -0.501875 -0.420654      -0.227897          -0.509442 -0.381955
# 49          -0.528006 -0.442852      -0.309976          -0.546763 -0.428829
# 50          -0.498843 -0.440026      -0.338687          -0.487885 -0.331429
# 51          -0.944419 -0.694836      -0.481556           -1.12706 -0.655521
# 52          -0.927071 -0.690897      -0.421453           -1.66514 -0.651854
# 53          -0.738083 -0.521846      -0.300538          -0.945084 -0.546282
# 54          -0.781471 -0.463598      -0.258855          -0.754561 -0.529514
# 55          -0.566128 -0.449588      -0.248574          -0.628796 -0.406382
# 56          -0.560772 -0.502691      -0.285158          -0.717435 -0.457468
# 57          -0.651627 -0.703695      -0.667084          -0.804207  -0.62168
# 58          -0.673544 -0.532756      -0.483159          -0.831435 -0.523565
# 59          -0.559325 -0.414322      -0.300997          -0.598362 -0.364839
# 60          -0.494943 -0.431488      -0.200898          -0.557227  -0.41539
# 61          -0.713823 -0.678583      -0.357652          -0.805034 -0.525037
# 62          -0.859817 -0.657072      -0.427511          -0.895718 -0.500954
# 63          -0.545244 -0.472018      -0.279262           -0.58449  -0.38734
# 64          -0.509479 -0.411159       -0.18269          -0.565129 -0.361546
# 65          -0.442861 -0.307343      -0.141437          -0.484338 -0.286622
#
#    Andhra Pradesh  Karnataka     Haryana Maharashtra  Nagaland
# 6       -0.256241  -0.239629   0.0967633   -0.278092 -0.381002
# 7       -0.504297  -0.147908 -0.00339337   -0.315167 -0.518983
# 8       -0.630517  -0.557503   -0.121769   -0.848557  -0.55057
# 9       -0.795249   -0.62063   -0.135183   -0.838006 -0.666949
# 10      -0.619087  -0.410434   -0.198196   -0.519135 -0.397636
# 11      -0.272378  -0.235312   0.0705032   -0.464428 -0.326829
# 12      -0.341036  -0.254443      0.2375   -0.276419 -0.390065
# 13      -0.420217  -0.235762    0.556721   -0.295679 -0.606003
# 14      -0.491335  -0.281351    0.111306   -0.382248 -0.632661
# 15      -0.477362   -0.20062   0.0739632   -0.284756 -0.709067
# 16       -0.33478  -0.148684    0.200321   -0.202906 -0.469435
# 17      -0.240707  -0.158347    0.149429   -0.184514 -0.547148
# 18      -0.208879  -0.139231    0.218416   -0.208486 -0.526027
# 19      -0.272399  -0.106523    0.146505   -0.259295 -0.418216
# 20      -0.413326  -0.199893    0.044548   -0.634353 -0.412163
# 21      -0.814998  -0.826017  -0.0668976   -0.609533 -0.459352
# 22      -0.553918  -0.699616   0.0719787   -0.345832 -0.573302
# 23      -0.403202   -0.24433    0.201281   -0.252086 -0.449108
# 24      -0.393768  -0.225121    0.228765   -0.280181 -0.232686
# 25      -0.332657  -0.130801    0.519444   -0.202216 -0.428262
# 26      -0.476442  -0.185542    0.275011   -0.272639 -0.459583
# 27      -0.436145   -0.19921    0.180526   -0.238565 -0.479773
# 28      -0.300542  -0.134418    0.280322   -0.179875 -0.509641
# 29      -0.107421  -0.146338    0.248032   -0.196997 -0.365878
# 30      -0.189776 -0.0799397    0.206888   -0.162297 -0.401625
# 31      -0.291716  -0.176659    0.141819   -0.270173 -0.556976
# 32      -0.384617  -0.237166    0.109804    -0.33084 -0.491163
# 33      -0.359099   -0.25999   0.0359466   -0.459551 -0.485893
# 34      -0.197863   -0.28305    0.114298   -0.284975   -0.4696
# 35      -0.328027  -0.189629    0.186318   -0.215043 -0.408811
# 36      -0.425523  -0.227731    0.446519   -0.284835 -0.419572
# 37      -0.645957  -0.325286    0.249283   -0.430479 -0.629119
# 38      -0.486036  -0.181434     0.25779    -0.20578 -0.306161
# 39      -0.348302  -0.132893   0.0452682   -0.253359 -0.411119
# 40      -0.192931 -0.0494484    0.171457   -0.126081 -0.383486
# 41       -0.23143  -0.137067    0.136628   -0.198492 -0.334014
# 42      -0.288259 -0.0992913    0.214314   -0.202124 -0.361363
# 43      -0.235031  -0.132063    0.157437   -0.259468 -0.408255
# 44      -0.527682  -0.246645    0.124717   -0.541227 -0.462138
# 45      -0.336904  -0.189839   0.0957988   -0.518299 -0.511918
# 46      -0.266902  -0.256132   0.0738887    -0.32393 -0.630695
# 47       -0.28536  -0.229382    0.140523   -0.232798 -0.425414
# 48      -0.329405    -0.1929    0.120233   -0.203122 -0.373674
# 49       -0.42884  -0.182842    0.435414   -0.173548 -0.374542
# 50      -0.404537  -0.146585    0.173912   -0.154225 -0.272964
# 51      -0.537208  -0.221508   0.0832642   -0.265146 -0.621787
# 52      -0.520855  -0.249517   0.0784216   -0.207895 -0.619132
# 53      -0.296413  -0.156153   0.0896401   -0.232347 -0.715797
# 54      -0.243329  -0.160204     0.14719     -0.2111 -0.607937
# 55      -0.174919  -0.117846    0.126554   -0.193444 -0.403846
# 56      -0.403047 -0.0393934    0.101181   -0.356534 -0.436033
# 57      -0.465806  -0.390978   0.0624099   -0.541798 -0.519235
# 58      -0.345546  -0.265058   -0.336427   -0.338928 -0.521306
# 59      -0.291263  -0.186902    0.154149   -0.240711 -0.420062
# 60      -0.322557  -0.179998    0.295632     -0.1834 -0.429422
# 61      -0.459248  -0.214178     0.20067   -0.257436 -0.493945
# 62      -0.508417  -0.222056   0.0737961    -0.25459 -0.402066
# 63        -0.3504  -0.183243    0.154642   -0.154337 -0.321564
# 64      -0.178676 -0.0998172    0.172085  -0.0571861 -0.341347
# 65      -0.158573  -0.109501    0.181703  -0.0781918 -0.347978
#
# [60 rows x 580 columns]

# %%
for state in set(states_list):
    print state
# Out:
# Haryana
# Punjab
# Goa
# Chhattisgarh
# Kerala
# ST_NM
# Dadara & Nagar Havelli
# Bihar
# Tamil Nadu
# Daman & Diu
# Jharkhand
# Meghalaya
# Assam
# Madhya Pradesh
# Lakshadweep
# West Bengal
# Rajasthan
# Uttar Pradesh
# Manipur
# Andhra Pradesh
# Himachal Pradesh
# Arunanchal Pradesh
# Nagaland
# Andaman & Nicobar Island
# Gujarat
# Maharashtra
# Uttarakhand
# Puducherry
# Karnataka
# Jammu & Kashmir
# Mizoram
# Odisha
# Sikkim

# %%
state_monthList = raw_states[raw_states['ST_NM'].dt.month == 6][state].sum(axis=1).values.tolist()

# %%
states_not_processed = list()

# %%
time_line = raw['DISTRICT'][6:-1].values.tolist()

# %%
time_line_years = [time_val.year for time_val in time_line]

# %%
time_line_months = [time_val.month for time_val in time_line]

# %%
month_name = ['0','jan','feb','mar','apr','may','jun','jul','aug','sep','oct','nov','dec']

# %%
for i in range(len(df_elections_dates)):
    state = df_elections_dates[i:i+1].values[0][0]
    month = df_elections_dates[i:i+1].values[0][1]
    year  = df_elections_dates[i:i+1].values[0][2]

    if not(month in time_line_months and year in time_line_years and state in states_list):
        states_not_processed.append([state,month,year])
        continue

    ## for state
    f_name = str(state)+'_' + str(month) +'_'+str(year)

    title = 'elections: '+ f_name

    file_name = f_name +'.png'

    dist_list = [raw_cols[i] for i,state_ in enumerate(raw[2:3].values.tolist()[0]) if state_==state]

    ## this is night light values according to state
    ntl_values = raw[dist_list][6:-1].sum(axis=1).values.tolist()

    np.shape(ntl_values)

    np.shape(time_line)

    A = range(len(time_line))
    B = ntl_values

    plt.plot(A,B)
    plt.plot(A,B,'ko')
    plt.title(title)
    plt.ylabel('raw_values')
    plt.grid()

    month_dates = list()
    month_vals = list()
    for i,time_value in enumerate(time_line):
        if time_value.month == month:
            ## putting the values in list
            month_vals.append(B[i])

            ## highlighting all that months
            data_label = month_name[time_value.month]+str(time_value.year)[2:]
            month_dates.append(data_label)
            plt.plot(A[i],B[i],'ko',markerfacecolor='None',markeredgecolor='black',markersize=15)
            plt.annotate(data_label,xy=(A[i]+1,B[i]))

            ## highlighting that year
            if time_value.year == year:
                year_val = B[i]
                plt.plot(A[i],B[i],'ks',markerfacecolor='None',markeredgecolor='black',markersize=15)

    month_std = np.std(month_vals,ddof=1)
    month_mean = np.mean(month_vals)

    std_year = (year_val - month_mean)/month_std

    plt.annotate('std: '+str(std_year) ,xy=(50,min(B)))

    std_all_years.append([state,std_year])

    plt.savefig('elections/'+file_name)

    plt.close()

# %%
df_stdCounts_allStates = pd.DataFrame(std_all_years)

# %%
df_stdCounts_allStates.columns = ['state','stdCount']

# %%
df_states_notProcessed = pd.DataFrame(states_not_processed)

# %%
df_states_notProcessed.columns = ['States','Month','Year']

# %%
df_sotdCounts_allStates.to_csv('elections/stdCounts_states')

# %%
df_states_notProcessed.to_csv('elections/notProcessedStates')
